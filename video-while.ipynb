# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt
import math

# %%
def distanciaBat(a,b,n=1): #la forma simple
    sumatoria=np.sum(np.sqrt(a*b)) #coeficiente de Bata
    return np.sqrt(n-sumatoria)    #0 si es igual

# %%
# video para leer
video= cv2.VideoCapture('360.mp4')
fps=video.get(cv2.CAP_PROP_FPS) 
size = (int(video.get(cv2.CAP_PROP_FRAME_WIDTH)), int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))) 

mbins=np.arange(0,360)

# Frame 1
i=0
success, frame = video.read()

hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
h1,s1,v1 = cv2.split(hsv); #h = hsv[:,:,0] 

#HIST1
hist1, bins = np.histogram(h1,bins=mbins,density=True)

while success:
    i+=1
    success, frame2 = video.read()
    if i <= 151:
        hsv2= cv2.cvtColor(frame2, cv2.COLOR_BGR2HSV)
        h2,s2,v2 = cv2.split(hsv2) 
        #HIST2
        hist2, bins = np.histogram(h2,bins=mbins,density=True)
        print(distanciaBat(hist1,hist2))
        hist1=hist2
# Out:
# 0.03241418762536388
# 0.03496764151617244
# 0.030029438118651535
# 0.028136025998274496
# 0.026974041398628138
# 0.029269669205257337
# 0.034883866038678574
# 0.03310496055480702
# 0.026572874343337625
# 0.029672686769942155
# 0.0317860698283866
# 0.029835210599543027
# 0.026246402488631977
# 0.03260001454622135
# 0.03451799973104412
# 0.027950737015254166
# 0.0333464374188081
# 0.03229769743786518
# 0.03438192545212296
# 0.032150452946596
# 0.03306612105782826
# 0.031785929780067924
# 0.03480843144417538
# 0.027553207761241108
# 0.02804653666205105
# 0.028398723648822916
# 0.03262652024497845
# 0.026729768931693706
# 0.028006513794333186
# 0.026507988126018803
# 0.027399713335268045
# 0.029381593974632456
# 0.02969722327963388
# 0.029086951521934478
# 0.03184571335678697
# 0.03500862465847972
# 0.029573534717842517
# 0.034737772221185306
# 0.03254432919463855
# 0.03396042766546767
# 0.03677539286448489
# 0.044848180426979085
# 0.03013871210989651
# 0.03109912607164215
# 0.032297041790380586
# 0.03245216905058664
# 0.033202952598627405
# 0.02826755123416353
# 0.03026750702904122
# 0.033701954284348364
# 0.029336048140780925
# 0.0332090757273314
# 0.040530157914527916
# 0.04013833180448415
# 0.025900685569151354
# 0.025314996241614447
# 0.042421381760410146
# 0.04515593915400846
# 0.03499410645504695
# 0.07416871220308331
# 0.03871961410210147
# 0.040721660408516935
# 0.04299037548415844
# 0.03739746952274261
# 0.04312252001384067
# 0.054547041642705435
# 0.05587786769942594
# 0.05159967875799555
# 0.04187662312842892
# 0.038048532981091926
# 0.040271306244900024
# 0.041076458700163236
# 0.04316675538424404
# 0.043424756937553474
# 0.03998311390909948
# 0.037975159445786236
# 0.04002995283891528
# 0.03849902032582618
# 0.036963881819349835
# 0.03926935044077749
# 0.039033157707088546
# 0.037871207642289934
# 0.035545087433993115
# 0.03643057146629695
# 0.04250167011453485
# 0.038627002961932
# 0.04085035729321396
# 0.034059368075005376
# 0.03375212877393714
# 0.04111564655287455
# 0.033029721380735774
# 0.033124882549385296
# 0.03136964193810827
# 0.031689013759784376
# 0.0335351514110474
# 0.03239190795708506
# 0.030722479723969368
# 0.03463536020907879
# 0.03356773870516632
# 0.0365833330668254
# 0.03365898506454953
# 0.037512168662763745
# 0.02996560192989605
# 0.034495782261935615
# 0.03797660074751567
# 0.0346741632958496
# 0.03302742889077366
# 0.035360120522107505
# 0.041229198372414864
# 0.03467599751837778
# 0.033679793066185085
# 0.03825073270938463
# 0.034100613509162624
# 0.02757458933825163
# 0.032905589681930705
# 0.03427412826760369
# 0.0331993291982396
# 0.034899378810256385
# 0.037002478712766865
# 0.10822190872719305
# 0.03413135331911979
# 0.03793983936360518
# 0.03785135909297807
# 0.035856894337097954
# 0.04175042312721977
# 0.04061608614223828
# 0.04268837785431002
# 0.04216302368203682
# 0.0419181567066021
# 0.03617320403890573
# 0.037211855527256754
# 0.03238165516265806
# 0.03797015161421622
# 0.036969651174320314
# 0.038234710389382164
# 0.036341069312403974
# 0.03199043690429689
# 0.03525832657259684
# 0.03738184895852929
# 0.03725802511928342
# 0.03665183029202197
# 0.04661443217423639
# 0.041398621300202255
# 0.05059700385901644
# 0.040742644334234725
# 0.038932990410498095
# 0.04558971086039031
# 0.044993633146143776
# 0.0493146391119582
# 0.04094884116729714
# 0.03832333218073904
