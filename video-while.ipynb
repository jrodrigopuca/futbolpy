# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt
import math

# %%
def distancia (a,b,n=1): 
    sumatoria=np.sum(np.sqrt(a*b))
    medio= 1/np.sqrt(np.average(a) * np.average(b)*n*n) 
    return math.sqrt((1-(medio*sumatoria)))

# %%
# video para leer
video= cv2.VideoCapture('360.mp4')
fps=video.get(cv2.CAP_PROP_FPS) 
cantFrames=video.get(cv2.CAP_PROP_POS_MSEC) #155 (hay 4 frames dañados)
size = (int(video.get(cv2.CAP_PROP_FRAME_WIDTH)), int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))) 

hbins=np.arange(0,179) # rango para canal H
vbins=np.arange(0,255) # rango para canal V

# Frame 1
i=0
success, frame = video.read()

hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
h1,s1,v1 = cv2.split(hsv); #h = hsv[:,:,0] 

#HIST1
hist1, bins = np.histogram(h1,bins=hbins,density=True)

while success:
    i+=1
    success, frame2 = video.read()
    if i <= 151:
        hsv2= cv2.cvtColor(frame2, cv2.COLOR_BGR2HSV)
        h2,s2,v2 = cv2.split(hsv2) 
        #HIST2
        hist2, bins = np.histogram(h2,bins=hbins,density=True)
        print(distancia(hist1,hist2, len(hbins)-1))
        hist1=hist2
# Out:
# 0.032066793552680994
# 0.03466394667566547
# 0.030025549452473908
# 0.02798978260876284
# 0.0269300745260856
# 0.029237051565232965
# 0.034876208815273736
# 0.033099306673798665
# 0.026248440156140636
# 0.029661392601647917
# 0.031708079237289216
# 0.029782851563686097
# 0.026049280976948103
# 0.032581287706010854
# 0.03446511498148463
# 0.02794581226575373
# 0.03329645964919347
# 0.03227645904779511
# 0.03435496814746996
# 0.03211360624721038
# 0.03298913946652782
# 0.031482331288434647
# 0.03474652742872751
# 0.0272573860768581
# 0.027676364710008672
# 0.028292834471940424
# 0.0326263114978751
# 0.026645550069590917
# 0.027830771832573733
# 0.026422122696332807
# 0.02720694093348681
# 0.02925564698217421
# 0.02944341865554986
# 0.028657279320400932
# 0.03172910620655287
# 0.03499898368907547
# 0.029570329402857688
# 0.03452058095352318
# 0.03238842856600959
# 0.03344123024624481
# 0.03654465683923062
# 0.04479165687247871
# 0.030089146119722136
# 0.030974818755351685
# 0.032181127106389866
# 0.0323229467339696
# 0.03282295914545087
# 0.028198592633887857
# 0.030220324512240493
# 0.03356655918488583
# 0.029185704912492318
# 0.033141549717616264
# 0.03951551657120963
# 0.039435732331230676
# 0.025517759579456376
# 0.02532048258312539
# 0.042230232078728044
# 0.04475546452533928
# 0.03456696441477942
# 0.07419038254152195
# 0.03873678976429709
# 0.04065975804990235
# 0.042811192200708836
# 0.03731459980893266
# 0.04295259697713468
# 0.05422751894234325
# 0.055373845259875876
# 0.0511098076837251
# 0.04187423077583796
# 0.037578464259665705
# 0.0402614782803819
# 0.04055534224903958
# 0.04238279435113475
# 0.043051501051753864
# 0.03963247053809379
# 0.03793031694685845
# 0.03986569666155402
# 0.03839395112152772
# 0.03654203850147149
# 0.03919624111859004
# 0.03889967800187988
# 0.03792235759187669
# 0.03496000953713642
# 0.036478550726878715
# 0.04236937737814958
# 0.03864980078829526
# 0.040459439529867344
# 0.034107168666131046
# 0.03383412422249339
# 0.040049433432322236
# 0.03287489701529481
# 0.032818998135966664
# 0.031135558167143303
# 0.031768954162429947
# 0.033572842049842844
# 0.03237708510349104
# 0.030828736084703247
# 0.03449763033292103
# 0.03368622129707445
# 0.036636543195811194
# 0.0335796306541873
# 0.037598078137312946
# 0.029930581542599855
# 0.03452842506239581
# 0.037857092116721634
# 0.03482517602770257
# 0.033066287458894776
# 0.03545103016799291
# 0.04123473184645436
# 0.034688019915756915
# 0.03363212909098095
# 0.03829115528630655
# 0.034227849061890206
# 0.02765018441573555
# 0.032899395181799955
# 0.03438830270880404
# 0.033146625220413437
# 0.03502232507156558
# 0.03707065129914606
# 0.10832220838731185
# 0.03416131552461645
# 0.03767617208744935
# 0.03790666763824135
# 0.03593742445586328
# 0.04175185092669468
# 0.04068555564770948
# 0.042655810829197255
# 0.04200271054545275
# 0.041956016888579875
# 0.03614311714396265
# 0.03662565145604624
# 0.032279492263977
# 0.0377818045363873
# 0.03690615567344986
# 0.03813007847301981
# 0.03578246417243144
# 0.031707997685694655
# 0.03511515779168314
# 0.037367282508042575
# 0.03713223576694863
# 0.03665561266556006
# 0.04643266445422137
# 0.0409446881826132
# 0.05033274040425628
# 0.04073535946910023
# 0.03887376049709162
# 0.04557860354516595
# 0.044798959751551855
# 0.04931602895378367
# 0.04095666638620633
# 0.03827288283784156
