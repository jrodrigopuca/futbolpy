# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt
import math

# %%
def distanciaBat(a,b,n=1): #la forma simple
    sumatoria=np.sum(np.sqrt(a*b)) #coeficiente de Bata
    return np.sqrt(n-sumatoria)    #0 si es igual

# %%
# video para leer
video= cv2.VideoCapture('test/diego.mp4')
fps=video.get(cv2.CAP_PROP_FPS) 
size = (int(video.get(cv2.CAP_PROP_FRAME_WIDTH)), int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))) 

hbins=np.arange(0,179) # rango para canal H
vbins=np.arange(0,255) # rango para canal V

# Frame 1
i=0
success, frame = video.read()

hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
h1,s1,v1 = cv2.split(hsv); #h = hsv[:,:,0] 

#HIST1
hist1, bins = np.histogram(h1,bins=hbins,density=True)

while success:
    i+=1
    success, frame2 = video.read()
    if i <= 171:
        hsv2= cv2.cvtColor(frame2, cv2.COLOR_BGR2HSV)
        h2,s2,v2 = cv2.split(hsv2) 
        #HIST2
        hist2, bins = np.histogram(h2,bins=hbins,density=True)
        print(distanciaBat(hist1,hist2))
        hist1=hist2
# Out:
# 0.05357336025205473
# 0.04887359853219199
# 0.03779624180650525
# 0.028053262170967506
# 0.030345459254920246
# 0.041649626718669536
# 0.03969358681813794
# 0.036210028085818295
# 0.035030512604663944
# 0.03183776386012881
# 0.03350150966479239
# 0.031061644375128945
# 0.031688397110742055
# 0.02532721694076771
# 0.02214761542458628
# 0.02825799670995805
# 0.026219714830200202
# 0.04626429130637647
# 0.05507238324722117
# 0.051252114815461144
# 0.04478358223088016
# 0.05475761328205005
# 0.058222035863710976
# 0.05304277673043563
# 0.03785893536379995
# 0.04252494235226965
# 0.04894466911662768
# 0.026077236946806307
# 0.038669935287401626
# 0.04290560939778635
# 0.02967873783145451
# 0.05040142468163815
# 0.03961185310889029
# 0.04077520721898388
# 0.03667136846274975
# 0.18716209305858872
# 0.3277215659245849
# 0.06796363026002453
# 0.06023169670595851
# 0.08960244117352616
# 0.07652095464427452
# 0.07072273408650916
# 0.07636800633857971
# 0.09691903362475969
# 0.06447484984732242
# 0.08650305734095197
# 0.1297617717836007
# 0.08442401722127339
# 0.08573784982947269
# 0.07165939576623652
# 0.0924182095274251
# 0.100508187748294
# 0.10006489804138122
# 0.09778614913394183
# 0.08587138774813863
# 0.08762951103326332
# 0.10891947186943476
# 0.11175071731886771
# 0.09368966830664169
# 0.087195176499653
# 0.10014770618534022
# 0.08486483833683878
# 0.10353457763239306
